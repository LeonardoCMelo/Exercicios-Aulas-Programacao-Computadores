# %%
# Função auxiliar de fatorial
def fat(n):
    res = 1;
    for i in range(1,n+1):
        res *= i
    return res

# %% [markdown]
# # Exercicio 01

# %% [markdown]
# ## 1.1

# %%
def exercicio_1_1(a,b):
    """
    Calcula a soma de forma recursiva
    
    Parâmetros:
        a: Primeiro Termo
        b: Segundo Termo
    
    Retorno:
        None se o valor de a ou b for negativo
        Se não retorna a soma de A e B
    """
    if a < 0 or b < 0:
        a = None
    elif b>0:
        a = exercicio_1_1(a+1, b-1)
    return a

# %% [markdown]
# ## 1.2

# %%
def exercicio_1_2(a, b):
    """
    Calcula a subtração de forma recursiva
    
    Parâmetros:
        a: Subtraendo
        b: Minuendo
    
    Retorno:
        None se o valor de a ou b for negativo
        Se não retorna a subtração de b pelo sub
    """
    if a < 0 or b < 0:
        b = None
    elif a > 0:
        b = exercicio_1_2(a - 1, b - 1)
    return b

# %% [markdown]
# ## 1.3

# %%
def exercicio_1_3(a,b):
    """
    Calcula a multiplicação de forma recursiva
    
    Parâmetros:
        a: Primeiro Termo
        b: Segundo Termo
    
    Retorno:
        None se o valor de a ou b for negativo
        0 se o valor de a ou b for 0
        Se não retorna a multiplicação de A por B
    """
    result = None
    if a < 0 or b < 0:
        result = None
    elif a == 0 or b == 0:
        result = 0
    elif b>0:
        result = a + exercicio_1_3(a, b-1)
    return result

# %% [markdown]
# ## 1.4

# %%
def exercicio_1_4(a, b):
    """
    Calcula a divisão entre dois números de forma recursiva.

    Parâmetros:
        a: Dividendo
        b: Divisor

    Retorno:
        None se o b for menor ou igual a zero
        0 se o b for maior que o a
        Se não retorna o resultado da divisão.
    """
    if b <= 0:
        return None
    if a < b or a == 0:
        return 0
    result = exercicio_1_4(a-b, b)
    return result + 1

# %% [markdown]
# ## 1.5

# %%
def exercicio_1_5(a,b):
    """
    Calcula a multiplicação de forma recursiva
    
    Parâmetros:
        a: Base
        b: Expoente
    
    Retorno:
        None se o valor de a ou b for negativo
        1 se o valor de b for 0 ou o valor de a for 1
        Se não retorna a multiplicação de A por B
    """
    if a < 0 or b < 0:
        return None
    if b == 0 or a == 1:
        return 1
    return a * exercicio_1_5(a, b-1)

# %% [markdown]
# ## 1.6

# %%
def exercicio_1_6(a,b):
    """
    Calcula o logaritmo inteiro (parte inteira de log_b(a)) de forma recursiva.

    Parâmetros:
        a: Base.
        b: Logaritmando.

    Retorno:
        Se a for menor ou igual a 1 ou b for menor ou igual a zero retorna None
        Se não retorna maior inteiro x tal que b^x <= a.
    """
    if a <= 1 or b <= 0:
        return None
    if b < a:   # caso base da recursão
        return 0
    return 1 + exercicio_1_6(a, b//a)

# %% [markdown]
# # Exercício 02

# %% [markdown]
# ## 2.1

# %%
def exercicio_2_1(n, i):
    """
    Calcula o fatorial de n de forma recursiva, usando o parâmetro auxiliar i que vai de 1 até n.

    Parâmetros:
        n: número inteiro não negativo cujo fatorial será calculado.
        i: contador auxiliar da recursão (inicia em 1).

    Retorno:
        Retorna o valor de n! (fatorial de n), ou None se n < 0.
    """
    if n < 0:
        resultado = None
    elif n == 0:
        resultado = 1
    elif i == n:
        resultado = n
    else:
        resultado = i * exercicio_2_1(n, i + 1)
    return resultado

# %% [markdown]
# ## 2.2

# %%
def exercicio_2_2(n):
    """
    Calcula o fatorial de n de forma iterativa.

    Parâmetros:
        n: número inteiro não negativo cujo fatorial será calculado.

    Retorno:
        Retorna o valor de n! (fatorial de n), ou None se n < 0.
    """
    resultado = 1
    i = 1

    if n == 0 or n == 1:
        return 1
    elif n < 0:
        return None
    while i <= n:
        resultado *= i
        i += 1
    return resultado

# %% [markdown]
# # Exercício 03

# %%
def exercicio3(n):
    sinal = 1
    if n<=0:
        result = None
    elif n==1:
        result = 1
    else:
        result = 0
        for i in range(1, n+1):
            result += sinal/i
            sinal = -sinal
    return result

# %% [markdown]
# # Exercício 04

# %% [markdown]
# # Exercício 04
# ---
# ### Versão euler_repI
#
# $ 1° Termo: \frac{1}{18} $<br>
# $ 2° Termo: \frac{1}{14+\frac{1}{18}}$<br>
# $ 3° Termo: \frac{1}{10+\frac{1}{14+\frac{1}{18}}}$<br>
# $ 4° Termo: \frac{1}{6+\frac{1}{10+\frac{1}{14+\frac{1}{18}}}}$<br>
# $ 5° Termo: \frac{2}{1+\frac{1}{6+\frac{1}{10+\frac{1}{14+\frac{1}{18}}}}}$ <br>
# $ 6° Termo: 1+\frac{2}{1+\frac{1}{6+\frac{1}{10+\frac{1}{14+\frac{1}{18}}}}} $ <br>
#
#
# ### Versão euler_repR
# $ 2° Termo: 1+2$<br>
# $ 2° Termo: 1+\frac{2}{1+...}$<br>
# $ 3° Termo: 1+\frac{2}{1+\frac{1}{6+...}}$<br>
# $ 4° Termo: 1+\frac{2}{1+\frac{1}{6+\frac{1}{10+...}}}$<br>
# $ 5° Termo: 1+\frac{2}{1+\frac{1}{6+\frac{1}{10+\frac{1}{14+...}}}}$<br>
# $ 6° Termo: 1+\frac{2}{1+\frac{1}{6+\frac{1}{10+\frac{1}{14+\frac{1}{18}}}}}$<br>

# %% [markdown]
# # Exercício 05

# %% [markdown]
# ## 5.1.1

# %%
def exercicio_5_1_1(n):
    result=0
    if n<0:
        result = None
    elif n==0:
        result = 1
    else:
        result = (1+exercicio_5_1_1(n-1))**(1/2)
    return result

# %% [markdown]
# ## 5.1.2

# %%
def exercicio_5_1_2(n):
    result = 0
    if n < 0:
        result = None
    else:
        for i in range(0,n):
            result = (1 + result)**(1/2)
    return result

# %% [markdown]
# ## 5.2.1

# %%
def exercicio_5_2_1(n):
    def calcPhi(n):
        result=0
        if n<0:
            result = None
        elif n==0:
            result = 1
        else:
            result = 1/(1+calcPhi(n-1))
        return result
    return calcPhi(n)+1

# %% [markdown]
# ## 5.2.2

# %%
def exercicio_5_2_2(n):
    result = 0
    if n < 0:
        result = None
    else:
        for i in range(0,n):
            result = 1/(1+result)
    return result + 1

# %% [markdown]
# ## 5.3.1

# %%
def exercicio_5_3_1(n):
    if n < 0:
        result = None
    elif n == 0:
        result = 1
    else:
        result = 1/fat(n) + exercicio_5_3_1(n-1)
    return result

# %% [markdown]
# ## 5.3.2

# %%
def exercicio_5_3_2(n):
    result = 0
    if n < 0:
        result = None
    else:
        for i in range(0,n+1):
            result += 1/fat(i)
    return result

# %% [markdown]
# ## 5.4.1

# %%
def exercicio_5_4_1(n,x):
    if n < 0:
        result = None
    elif n == 0:
        result = 1
    else:
        result = (x**n)/fat(n) + exercicio_5_4_1(n-1,x)
    return result

# %% [markdown]
# ## 5.4.2

# %%
def exercicio_5_4_2(n,x):
    result = 0
    if n < 0:
        result = None
    else:
        for i in range(0,n+1):
            result += (x**i)/fat(i)
    return result

# %% [markdown]
# ## 5.5.1

# %%
def exercicio_5_5_1(n):
    if n < 0:
        result = None
    elif n == 0:
        result = 1
    else:
        result = (1 if n%2==0 else -1)/fat(n) + exercicio_5_5_1(n-1)
    return result

# %% [markdown]
# ## 5.5.2

# %%
def exercicio_5_5_2(n):
    result = 0
    if n < 0:
        result = None
    else:
        for i in range(0,n+1):
            result += (1 if i%2==0 else -1)/fat(i)
    return result

# %% [markdown]
# ## 5.6.1

# %%
def exercicio_5_6_1(n):
    if n<0:
        result = None
    elif n==0:
        result = 3
    else:
        term = 2*n
        result = (-1 if n%2 == 0 else 1)*(4/((term)*(term+1)*(term+2))) + exercicio_5_6_1(n-1)
    return result

# %% [markdown]
# ## 5.6.2

# %%
def exercicio_5_6_2(n):
    if n<0:
        result = None
    else:
        result = 3
        for i in range(1,n+1):
            term = 2*i
            result += (-1 if i%2 == 0 else 1)*(4/((term)*(term+1)*(term+2)))
    return result

# %% [markdown]
# ## 5.7.1

# %%
def exercicio_5_7_1(n):
    if n < 0:
        result = None
    elif n == 0:
        result = 0
    elif n == 1:
        result = 1
    else:
        return exercicio_5_7_1(n-1) + exercicio_5_7_1(n-2)
    return result

# %% [markdown]
# ## 5.7.2

# %%
def exercicio_5_7_2(n):
    if n == 0: 
        result = 0
    elif n == 1:
        result = 1
    else:
        a = 0
        b = 1
        for i in range(2,n+1):
            temp = a+b
            a = b
            b = temp
        result = b
    return result

# %% [markdown]
# ## 5.8.1

# %%
def exercicio_5_8_1(n):
    def sqrt3(n):
        if n < 0:
            result = None
        elif n == 0:
            result = 1
        else:
            result = 1/((1 if n%2 == 0 else 2 ) + sqrt3(n-1))
        return result
    return sqrt3(n) + 1

# %% [markdown]
# ## 5.8.2

# %%
def exercicio_5_8_2(n):
    if n < 0:
        result = None
    else:
        result = 0
        for i in range(1,n+1):
            result = 1/((1 if i%2 == 0 else 2 ) + result)
    return result + 1

# %% [markdown]
# ## 5.9.1

# %%
def exercicio_5_9_1(n):
    def sqrt2(n):
        if n < 0:
            result = None
        elif n == 0:
            result = 0
        else:
            result = 1/(2+sqrt2(n-1))
        return result
    return sqrt2(n)+1

# %% [markdown]
# ## 5.9.2

# %%
def exercicio_5_9_2(n):
    if n < 0:
        result = None
    else:
        result = 0
        for i in range(0,n):
            result = 1/(2 + result)
    return result + 1

# %% [markdown]
# ## 5.10

# %%
def exercicio_5_9_1(n):
    def sqrt2(n):
        if n < 0:
            result = None
        elif n == 0:
            result = 0
        else:
            result = 1/(2+sqrt2(n-1))
        return result
    return sqrt2(n)+1

# %% [markdown]
# ## 5.11.1

# %%
def exercicio_5_11_1(n,x):
    def tan(n, x, k):
        if n<0:
            result = None
        elif n == 0:
            result = 1
        else:
            result = (k / x) - (1 / tan(n - 1, x, k+2))
        return result
    return 1/tan(n,x,1)

# %% [markdown]
# ## 5.11.2

# %%
def exercicio_5_11_2(n,x):
    if n<0:
        result = None
    else:
        result = 1
        for i in range(n,0,-2):
            result = i/x - (1/result)
    return 1/result

# %% [markdown]
# ## 5.12.1

# %%
def exercicio_5_12_1(n,):
    def neper(n,i):
        if n<0:
            result = None
        elif n == 0:
            result = 1
        else:
            result = i/(i+neper(n-1,i+1))   
        return result
    return 2 + (2/neper(n,2))

# %% [markdown]
# ## 5.12.2

# %%
def exercicio_5_12_2(n):
    result = 1

    for i in range(n, 0, -1):
        result = i / (i + result)
    return 2 + (2 / result)
