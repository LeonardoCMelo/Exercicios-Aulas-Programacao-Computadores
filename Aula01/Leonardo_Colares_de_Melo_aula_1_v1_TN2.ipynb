# %% [markdown]
# # Exercício 1

# %% [markdown]
# ### Algoritmo de soma
# Alinhe os números um sobre o outro de acordo pela casa decimal<br>
# Para cada algarismo nos termos:<br>
# &emsp;Para cada algaritmo faça a soma individual<br>
# &emsp;Adicionar o **vc** da casa anterior<br>
# &emsp;Se valor individual da soma for maior que 10:<br>
# &emsp;&emsp;Salvar o valor da (soma individual módulo 10)/10 em **vc**<br>
# &emsp;Mover para a coluna de algarismos seguinte<br>
# Se algum dos termos tiver casas decimais (mantissa):<br>
# &emsp;Colocar alinhado com a vírgula dos termos<br>

# %% [markdown]
# ### Algoritmo de Subtração
# Alinhe os números um sobre o outro de acordo com a casa decimal<br>
# Para cada coluna dos termos:<br>
# &emsp;Se o dígito do minuendo for menor que o do subtraendo:<br>
# &emsp;&emsp;Subtrair 1 unidade do digito seguinte<br>
# &emsp;&emsp;Adicionar 10 ao dígito atual do minuendo<br>
# &emsp;Subtraia o dígito do minuendo pelo subtraendo<br>
# Se algum dos termos tiver casas decimais (mantissa):<br>
# &emsp;Colocar alinhado com a vírgula dos termos<br>
# Se o minuendo for menor que o subtraendo:<br>
# &emsp;Colocar um sinal negativo no final

# %% [markdown]
# ### Algoritmo de multiplicação
# Alinhe os números um sobre o outro<br>
# Para cada algarismo no **multiplicador**:<br>
# &emsp;Para cada algarismo no **multiplicando**:<br>
# &emsp;&emsp;Multiplique o algarismo do **multiplicando** com o algarismo do **multiplicador**<br>
# &emsp;&emsp;Adicione ao valor multiplicado (**vm**) o **vc** da casa anterior<br>
# &emsp;&emsp;Se o **vm** for maior que 10:<br>
# &emsp;&emsp;&emsp;Salvar o valor do (vm módulo 10)/10 em **vc**<br>
# &emsp;&emsp;Mova para o próximo algarismo do **multiplicando**<br>
# &emsp;Mova uma casa abaixo e esquerda do último valor parcial<br>
# &emsp;Mova para o próximo algarismo do **multiplicador**<br>
# Some todos os valores parciais<br>
# Se o **multiplicador** ou o **multiplicando** tiver casas decimais (mantissa):<br>
# &emsp;Mova a vírgula para a esquerda de acordo com o número de casas somadas do **multiplicador** e do **multiplicando**<br>

# %% [markdown]
# ### Algoritmo de Divisão
# Alinhe o **Divisor** a esquerda do **Dividendo**<br>
# Se o **Divisor** ou **Dividendo** tiverem casas decimais:<br>
# &emsp;Multiplicar os dois por 10 até não sobrar nenhuma casa decimal<br>
# Se o **Divisor** > **Dividendo**:<br>
# &emsp;**Quociente** = 0<br>
# &emsp;**Resto** = **Dividendo**<br>
# Caso contrário:<br>
# &emsp;Faça:<br>
# &emsp;&emsp;Traga os algarismos até formar um número maior ou igual ao **Divisor**<br>
# &emsp;&emsp;Salve esse valor em **DV**<br>
# &emsp;&emsp;Faça a divisão inteira do **DV** pelo **Divisor**<br>
# &emsp;&emsp;Anote o resultado da divisão parcial abaixo do **Divisor**<br>
# &emsp;&emsp;Multiplique o Resultado pelo **Divisor** e subtraia de **DV**<br>
# &emsp;&emsp;Se acabou os algarismos e o **Resto** < que o **Divisor**:<br>
# &emsp;&emsp;&emsp;Adicione uma vírgula ao final do quociente parcial<br>
# &emsp;&emsp;&emsp;Adicione um zero ao **Resto**<br>
# &emsp;Repita enquanto o **Resto** > 0<br>

# %% [markdown]
# ### Algoritmo de Exponenciação
#
# Seja $ a^{b} $:
#
# Dê o valor 1 a variável **resultado**<br>
# Repita por **b** vezes:<br>
# &emsp;Multiplique **resultado** por **a** e salve nele mesmo<br>
#
# O valor total é **resultado**

# %% [markdown]
# ### Algoritmo para Logaritmo
# Seja $ \log_{y} x = y $:<br><br>
# Dê o valor 1 para a variável **potencia**<br>
# Dê o valor nulo para a variável **x**<br>
# Enquanto a **potencia** for menor que **y**:<br>
# &emsp;Multiplique a **potencia** por **b** e salve<br>
# &emsp;Some 1 a **x** e salve<br>
# Se **potencia** for igual a **y**:<br>
# &emsp;O valor é **x**<br>
# Senão:<br>
# &emsp;O valor não é natural<br>

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# Colocar a marca superior (**ms**) sobre o primeiro número da sequência<br>
# Enquanto **ms** não estiver sobre o penúltimo número da sequência:<br>
# &emsp;A partir de **ms** até o final:<br>
# &emsp;&emsp;Procurar o menor número na sequência<br>
# &emsp;&emsp;Trocar o menor número encontrado com o número marcado pela **ms**<br>
# &emsp;Avançar a **ms** para a próxima posição à direita<br>
