# %% [markdown]
# Para simplificar a simbologia, estarei utilizando:
# ">" = maior que
# "<" = menor que
# "|" = ou
# "&" = e
# "!" = não
# "=" = igual

# %% [markdown]
# # Exercicio 1

# %% [markdown]
# **1.1.** X > Y | X = Y<br>
# **1.2.** X < Y | X = Y<br>
# **1.3.** X ! Y<br>
# **1.4.** (X > 0 | X = 0) & (X < INFINITO | X = INFINITO)<br>
# **1.5.** (!X < 0 | X ! 0) | (Y > 0 | Y = 0)<br>
# **1.6.** (!(X < 0 | X = 0)|(Y > 0 | Y = 0)) & (!(Y > 0 | Y = 0) | (X < 0 | X = 0))<br>
