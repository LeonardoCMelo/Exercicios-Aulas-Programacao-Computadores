# %% [markdown]
# Para simplificar a simbologia, estarei utilizando:<br>
# ">" = maior que<br>
# "<" = menor que<br>
# "|" = ou<br>
# "&" = e<br>
# "!" = não<br>
# "=" = igual<br>

# %% [markdown]
# # Exercício 1

# %% [markdown]
# **1.1.** X > Y | X = Y<br>
# **1.2.** X < Y | X = Y<br>
# **1.3.** X ! Y<br>
# **1.4.** (X > 0 | X = 0) & (X < INFINITO | X = INFINITO)<br>
# **1.5.** X < 0 | X = 0 | Y < 0<br>
# **1.6.** (X > 0 | Y > 0 | Y = 0) & (Y < 0 | X < 0 | X = 0)<br>

# %% [markdown]
# # Exercício 2

# %% [markdown]
# 1.1.
# |  X  |  Y  | X > Y | X = Y | X ≥ Y |
# |:---:|:---:|:-----:|:-----:|:-----:|
# | 1   | 20  |False  |False  |False  |
# | 20  | 20  |False  |True   |True   |
# | 20  | 1   |True   |False  |True   |

# %% [markdown]
# 1.2.
# |  X  |  Y  | X < Y | X = Y | X ≤ Y |
# |:---:|:---:|:-----:|:-----:|:-----:|
# | 1   | 20  |True   |False  |True   |
# | 20  | 20  |False  |True   |True   |
# | 20  | 1   |False  |False  |False  |

# %% [markdown]
# 1.3.
# |  X  |  Y  | X ! Y |
# |:---:|:---:|:-----:|
# | 1   | 20  |True   |
# | 20  | 20  |False  |
# | 20  | 1   |True   |

# %% [markdown]
# 1.4.
# | X   | X > 0   | X = 0   | X < ∞          | X =  ∞         | X ≥ 0   | X ≤ ∞     | X ≥ 0 & X ≤ ∞   |
# |:---:|:-------:|:-------:|:--------------:|:--------------:|:-------:|:---------:|:---------------:|
# | -1  | False   | False   | True           | False          |False    | True      | False           |
# | 0   | False   | True    | True           | False          |True     | True      | True            |
# | 1   | True    | False   | True           | False          |True     | True      | True            |
# | ∞   | True    | False   | False          | True           |True     | True      | True            |

# %% [markdown]
# 1.5.
# | X  | Y  | X < 0 | X = 0 | Y < 0 | X > 0 → Y ≥ 0 |
# |----|----|-------|-------|-------|---------------|
# | -1 | -1 | True  | False | True  | True          |
# | 0  | -1 | False | True  | True  | True          |
# | -1 |  0 | True  | False | False | True          |
# | 0  |  0 | False | True  | False | True          |
# | -1 |  1 | True  | False | False | True          |
# | 1  | -1 | False | False | True  | True          |
# | 0  |  1 | False | True  | False | False         |
# | 1  |  0 | False | False | False | False         |
# | 1  |  1 | False | False | False | False         |

# %% [markdown]
# 1.6.
# |   X  |   Y  |  X<0  |  X>0  |  X=0  |  Y<0  |  Y>0  |  Y=0  | X > 0 ∨ Y≥0 | Y<0 ∨ X≤0 | X≤0 ↔ Y≥0 |
# |:----:|:----:|-------|-------|-------|-------|-------|-------|-------------|-----------|-----------|
# |  -1  |  -1  | True  | False | False | True  | False | False | False       | True      | False     |
# |  -1  |   0  | True  | False | False | False | False | True  | True        | True      | True      |
# |   0  |  -1  | False | False | True  | True  | False | False | False       | True      | False     |
# |   0  |   0  | False | False | True  | False | False | True  | True        | True      | True      |
# |   0  |   1  | False | False | True  | False | True  | False | True        | True      | True      |
# |   1  |   0  | False | True  | False | False | False | True  | True        | False     | False     |
# |   1  |   1  | False | True  | False | False | True  | False | True        | False     | False     |
# |  -1  |   1  | True  | False | False | False | True  | False | True        | True      | True      |
# |   1  |  -1  | False | True  | False | True  | False | False | True        | True      | True      |

# %% [markdown]
# # Exercício 3

# %% [markdown]
# 3.1.
# |   A   |   B   | A ⊗ B |
# |:-----:|:-----:|:------:|
# |False  |False  |False   |
# |False  |True   |True    |
# |True   |False  |True    |
# |True   |True   |False   |
#
# 3.2.
# (!A & B) | (A & !B)

# %% [markdown]
# # Exercício 4

# %% [markdown]
# |  A  |  B  | A → B | B → A | A ↔ B |
# |-----|-----|-------|-------|-------|
# |False|False|True   |True   |True   |
# |False|True |True   |False  |False  |
# |True |False|False  |True   |False  |
# |True |True |True   |True   |True   |
#
# Uma é o inverso da outra

# %% [markdown]
# # Exercício 5

# %% [markdown]
# 5.1. X > Y<br>
# 5.2. X < Y | X = Y<br>
# 5.3. (X > Y | X = Y) & (X < Y) (False)<br>
# 5.4. X < Y | X = Y | X > Y (True)<br>
# 5.5. (0 < X | 0 = X) & (X < 10 | x = 10)<br>
# 5.6. !A & B<br>
# 5.7. A | B<br>
# 5.8. A & !B<br>
# 5.9. A | B<br>

# %% [markdown]
# # Exercício 6

# %%
A=False; B=False
print(f"+{str('-')*29}+")
print(f"|{str('Ex 5.6').center(29,' ')}|")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*13}+")
print(f"| {str('A').center(5,' ')} | {str('B').center(5,' ')} | {str('¬(A ∨ ¬B)').center(11,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*13}+")
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or not(B))).center(11,' ')} |")
A=False; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or not(B))).center(11,' ')} |")
A=True; B=False
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or not(B))).center(11,' ')} |")
A=True; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or not(B))).center(11,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*13}+")
# Out:
# +-----------------------------+
# |            Ex 5.6           |
# +-------+-------+-------------+
# |   A   |   B   |  ¬(A ∨ ¬B)  |
# +-------+-------+-------------+
# | False | False |    False    |
# | False |  True |     True    |
# |  True | False |    False    |
# |  True |  True |    False    |
# +-------+-------+-------------+

# %%
A=False; B=False
print(f"+{str('-')*26}+")
print(f"|{str('Ex 5.7').center(26,' ')}|")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+")
print(f"| {str('A').center(5,' ')} | {str('B').center(5,' ')} | {str('A | B').center(8,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+")
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A or B).center(8,' ')} |")
A=False; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A or B).center(8,' ')} |")
A=True; B=False
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A or B).center(8,' ')} |")
A=True; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A or B).center(8,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+")
# Out:
# +--------------------------+
# |          Ex 5.7          |
# +-------+-------+----------+
# |   A   |   B   |  A | B   |
# +-------+-------+----------+
# | False | False |  False   |
# | False |  True |   True   |
# |  True | False |   True   |
# |  True |  True |   True   |
# +-------+-------+----------+

# %%
A=False; B=False
print(f"+{str('-')*26}+")
print(f"|{str('Ex 5.8').center(26,' ')}|")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+")
print(f"| {str('A').center(5,' ')} | {str('B').center(5,' ')} | {str('A & !B').center(8,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+")
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A and not(B)).center(8,' ')} |")
A=False; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A and not(B)).center(8,' ')} |")
A=True; B=False
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A and not(B)).center(8,' ')} |")
A=True; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(A and not(B)).center(8,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+")
# Out:
# +--------------------------+
# |          Ex 5.8          |
# +-------+-------+----------+
# |   A   |   B   |  A & !B  |
# +-------+-------+----------+
# | False | False |  False   |
# | False |  True |  False   |
# |  True | False |   True   |
# |  True |  True |  False   |
# +-------+-------+----------+

# %%
A=False; B=False
print(f"+{str('-')*28}+")
print(f"|{str('Ex 5.9').center(28,' ')}|")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*12}+")
print(f"| {str('A').center(5,' ')} | {str('B').center(5,' ')} | {str('¬(¬A ∧ ¬B)').center(10,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*12}+")
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(not(A) and not(B))).center(10,' ')} |")
A=False; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(not(A) and not(B))).center(10,' ')} |")
A=True; B=False
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(not(A) and not(B))).center(10,' ')} |")
A=True; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(not(A) and not(B))).center(10,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*12}+")
# Out:
# +----------------------------+
# |           Ex 5.9           |
# +-------+-------+------------+
# |   A   |   B   | ¬(¬A ∧ ¬B) |
# +-------+-------+------------+
# | False | False |   False    |
# | False |  True |    True    |
# |  True | False |    True    |
# |  True |  True |    True    |
# +-------+-------+------------+

# %% [markdown]
# # Exercício 7
# O 5.7 e o 5.9

# %% [markdown]
# # Exercício 8

# %%
A=False; B=False
print(f"+{str('-')*37}+")
print(f"|{str('Exercicio 8.1').center(37,' ')}|")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+{str('-')*10}+")
print(f"| {str('A').center(5,' ')} | {str('B').center(5,' ')} | {str('¬(A V B)').center(8,' ')} | {str('¬A ∧ ¬B').center(8, ' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+{str('-')*10}+")
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A and B)).center(8,' ')} | {str(not(A) or not(B)).center(8,' ')} |")
A=False; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A and B)).center(8,' ')} | {str(not(A) or not(B)).center(8,' ')} |")
A=True; B=False
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A and B)).center(8,' ')} | {str(not(A) or not(B)).center(8,' ')} |")
A=True; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A and B)).center(8,' ')} | {str(not(A) or not(B)).center(8,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+{str('-')*10}+")
# Out:
# +-------------------------------------+
# |            Exercicio 8.1            |
# +-------+-------+----------+----------+
# |   A   |   B   | ¬(A V B) | ¬A ∧ ¬B  |
# +-------+-------+----------+----------+
# | False | False |   True   |   True   |
# | False |  True |   True   |   True   |
# |  True | False |   True   |   True   |
# |  True |  True |  False   |  False   |
# +-------+-------+----------+----------+

# %%
A=False; B=False
print(f"+{str('-')*37}+")
print(f"|{str('Exercicio 8.2').center(37,' ')}|")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+{str('-')*10}+")
print(f"| {str('A').center(5,' ')} | {str('B').center(5,' ')} | {str('¬(A V B)').center(8,' ')} | {str('¬A ∧ ¬B').center(8, ' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+{str('-')*10}+")
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or B)).center(8,' ')} | {str(not(A) and not(B)).center(8,' ')} |")
A=False; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or B)).center(8,' ')} | {str(not(A) and not(B)).center(8,' ')} |")
A=True; B=False
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or B)).center(8,' ')} | {str(not(A) and not(B)).center(8,' ')} |")
A=True; B=True
print(f"| {str(A).center(5,' ')} | {str(B).center(5,' ')} | {str(not(A or B)).center(8,' ')} | {str(not(A) and not(B)).center(8,' ')} |")
print(f"+{str('-')*7}+{str('-')*7}+{str('-')*10}+{str('-')*10}+")
# Out:
# +-------------------------------------+
# |            Exercicio 8.2            |
# +-------+-------+----------+----------+
# |   A   |   B   | ¬(A V B) | ¬A ∧ ¬B  |
# +-------+-------+----------+----------+
# | False | False |   True   |   True   |
# | False |  True |  False   |  False   |
# |  True | False |  False   |  False   |
# |  True |  True |  False   |  False   |
# +-------+-------+----------+----------+
